# %%
import os
from ultralytics import YOLO

# %%
# !nvidia-smi
# Out:
# Sat May 25 10:03:34 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 546.80                 Driver Version: 546.80       CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3060 ...  WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   51C    P0              27W /  80W |      0MiB /  6144MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
model = YOLO('G:\Yolo_Hand\pre_trained_pose_models\yolo_v8\yolov8n-pose.pt')

# %%
model.train(data='config.yaml', epochs=50, imgsz=224)
# Out:
# Ultralytics YOLOv8.2.15  Python-3.10.5 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
model = YOLO(r"G:\Yolo_Hand\training\runs\pose\train\weights\best.pt")

# %%
model.train(data='config.yaml', epochs=80, imgsz=224)
# Out:
# Ultralytics YOLOv8.2.15  Python-3.10.5 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
model = YOLO(r"G:\Yolo_Hand\training\runs\pose\train2\weights\last.pt")

# %%
model.train(data='config.yaml', epochs=120, imgsz=224)
# Out:
# Ultralytics YOLOv8.2.15  Python-3.10.5 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
model = YOLO(r"G:\Yolo_Hand\training\runs\pose\train\weights\best.pt")

# %%
model.train(data='config.yaml', epochs=200, imgsz=224)
# Out:
# Ultralytics YOLOv8.2.15  Python-3.10.5 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...
